# %%
import pandas as pd
import api_functions as af
import db_functions  as db
import get_clean_data as cd
from firebase import Firebase #https://github.com/mikexstudios/python-firebase

# %%
#db.get_senadores_list()

# %%
db.get_votos_senador('3')
# Out:
# {u'LS': {u'115831': {u'AnoMateria': u'2013',
#    u'DescricaoResultado': u'Aprovado',
#    u'DescricaoVotacao': u'D\xe1 nova reda\xe7\xe3o ao art. 42 do ADCT, ampliando o prazo em que a Uni\xe3o dever\xe1 destinar as Regi\xf5es Centro-Oeste e Nordeste percentuais m\xednimos dos recursos destinados \xe0 irriga\xe7\xe3o.',
#    u'DescricaoVoto': u'LS ',
#    u'SiglaSubtipoMateria': u'PEC'},
#   u'118636': {u'AnoMateria': u'2014',
#    u'DescricaoResultado': u'N\xe3o Informado',
#    u'DescricaoVotacao': u'Prev\xea que a revis\xe3o da base de c\xe1lculo do IPTU e a atualiza\xe7\xe3o monet\xe1ria dos valores que a comp\xf5em constituem requisitos essenciais da responsabilidade na gest\xe3o fiscal.',
#    u'DescricaoVoto': u'LS ',
#    u'SiglaSubtipoMateria': u'PLS'},
#   u'121373': {u'AnoMateria': u'2015',
#    u'DescricaoResultado': u'N\xe3o Informado',
# ...

# %%
votos = db.get_votos_senador('3')

# %%
pd.DataFrame(votos['Sim'].items())
# Out:
#          0                                                  1
# 0   102107  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 1   112691  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 2   122646  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 3    99256  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 4    99067  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 5   122324  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 6   105947  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 7   100475  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 8   108259  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 9   116962  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 10  113104  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 11   99546  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 12  106347  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# 13  108759  {u'DescricaoVoto': u'Sim', u'SiglaSubtipoMater...
# ...
